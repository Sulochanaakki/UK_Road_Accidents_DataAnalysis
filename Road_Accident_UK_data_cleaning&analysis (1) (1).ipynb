# %% [markdown]
# # UK Road Traffic Accidents
#
# <img src="/work/media/1617925592_maxresdefault.jpg">
#
# The goal of this project is to analyse accidents and traffic data in the United Kingdom.The data are available for download on [link to data](https://data.world/datagov-uk/6efe5505-941f-45bf-b576-4c1e09b579a1) and contain UK government records of accidents from 2009 to 2018.Using python and its modules pandas, numpy, glob, folium and seaborn we will visualise different aspects of the data and try to get some insight into trends and evolution of accidents and traffic in the UK.
#
# .The datasets contains 15 features,
# - Reference Number
# - Easting
# - Northing
# - Number of Vehicles
# - Accident Date
# - Time (24hr)
# - 1st Road Class
# - Road Surface
# - Lighting Conditions
# - Weather Conditions
# - Casualty Class
# - Casualty Class.1
# - Casualty Severity
# - Sex of Casualty
# - Age of Casualty
# - Type of Vehicle
#
# Among these features there are two geospatial specific features namely eastings and northings of accidents.Given the easting and northing of a location, we can calculate the latitude and longitude of the location and vice versa.
#
# All of the above features are making very interesting and comprehensive  for analysis and research.

# %% [markdown]
# ## Importing  and Merging

# %% [markdown]
# ### Importing the necessary libraries

# %%
# !pip install convertbng==0.6.32
# Out:
# Requirement already satisfied: convertbng==0.6.32 in /home/sulochana/miniconda3/lib/python3.9/site-packages (0.6.32)
# Requirement already satisfied: numpy>=1.11.0 in /home/sulochana/miniconda3/lib/python3.9/site-packages (from convertbng==0.6.32) (1.21.2)

# %%
import glob
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import calendar
import folium
from convertbng.util import convert_lonlat
#from pandas_profiling import ProfileReport
# %matplotlib inline

# %% [markdown]
# ### Reading data files and Data Cleaning
# - As shown below, there are discrepencies with the column names
# - We are editing the individual csv files before merging them

# %% [markdown]
# #### Data for 2009
# - We are taking this file as the base file to edit the next years of data.
# - By base file, it is meant that, the column names and data types will be identical to this file.

# %%
data_2009 = pd.read_csv("data/2009-9.csv",encoding='cp1252')

# %%
data_2009.head()
# Out:
#    Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0              3309   429093    436258                   1     01-Jan-09
# 1              2609   434723    435534                   1     02-Jan-09
# 2              2809   441173    433047                   1     02-Jan-09
# 3              3809   428487    431364                   1     02-Jan-09
# 4              3909   425928    435480                   2     02-Jan-09
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0           55   Unclassified          Dry
# 1         2335   Unclassified          Dry
# 2         1645   Unclassified          Dry
# 3         1723              A          Dry
# 4         1350   Unclassified          Dry
#
#                        Lighting Conditions       Weather Conditions  \
# 0  Darkness: street lights present and lit  Fine without high winds
# 1  Darkness: street lights present and lit  Fine without high winds
# 2  Darkness: street lights present and lit  Fine without high winds
# 3  Darkness: street lights present and lit  Fine without high winds
# 4          Daylight: street lights present  Fine without high winds
#
#   Casualty Class Casualty Severity Sex of Casualty  Age of Casualty  \
# 0     Pedestrian            Slight            Male               44
# 1         Driver           Serious          Female               23
# 2     Pedestrian            Slight          Female               12
# 3     Pedestrian            Slight            Male               15
# 4         Driver            Slight          Female               34
#
#   Type of Vehicle
# 0             Car
# 1             Car
# 2             Car
# 3             Car
# 4             Car

# %%
data_2009.shape
# Out:
# (3057, 15)

# %% [markdown]
# #### Data for 2010
# - No changes made, identical with base file (2009)

# %%
data_2010 = pd.read_csv("data/2010-3.csv",encoding='cp1252')

# %%
data_2010.head()
# Out:
#   Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0      10BA0000011   430408    437054                   2     01-Jan-10
# 1      10BA0000014   435011    436276                   2     01-Jan-10
# 2      10BA0000037   430429    437764                   1     01-Jan-10
# 3      10BA0000064   429002    436842                   2     01-Jan-10
# 4      10CA0000023   429399    433811                   2     01-Jan-10
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0         1650   Unclassified   Wet / Damp
# 1          205   Unclassified   Wet / Damp
# 2          124   Unclassified   Frost/ Ice
# 3          550   Unclassified   Wet / Damp
# 4         1825           A(M)   Wet / Damp
#
#                        Lighting Conditions          Weather Conditions  \
# 0  Darkness: street lights present and lit  Snowing without high winds
# 1  Darkness: street lights present and lit     Fine without high winds
# 2  Darkness: street lights present and lit     Fine without high winds
# 3  Darkness: street lights present and lit     Fine without high winds
# 4  Darkness: street lights present and lit     Fine without high winds
#
#   Casualty Class Casualty Severity Sex of Casualty  Age of Casualty  \
# 0         Driver            Slight          Female               62
# 1      Passenger            Slight            Male               36
# 2     Pedestrian            Slight          Female               34
# 3         Driver            Slight            Male               27
# 4         Driver            Slight            Male               18
#
#                           Type of Vehicle
# 0                                     Car
# 1  Goods vehicle 3.5 tonnes mgw and under
# 2  Goods vehicle 3.5 tonnes mgw and under
# 3                                     Car
# 4                                     Car

# %%
data_2010.shape
# Out:
# (2765, 15)

# %% [markdown]
# #### Data for 2011
# - No changes made, identical with base file (2009)

# %%
data_2011 = pd.read_csv("data/2011-1.csv",encoding='cp1252')

# %%
data_2011.head()
# Out:
#    Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0         110000115   423323    432051                   1     01-Jan-11
# 1         110000165   436292    434793                   2     01-Jan-11
# 2         110000165   436292    434793                   2     01-Jan-11
# 3         110000399   426469    435290                   4     01-Jan-11
# 4         110000399   426469    435290                   4     01-Jan-11
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0          200   Unclassified   Wet / Damp
# 1          315   Unclassified          Dry
# 2          315   Unclassified          Dry
# 3          710              A          Dry
# 4          710              A          Dry
#
#                        Lighting Conditions       Weather Conditions  \
# 0  Darkness: street lights present and lit  Fine without high winds
# 1  Darkness: street lights present and lit  Fine without high winds
# 2  Darkness: street lights present and lit  Fine without high winds
# 3        Darkness: street lighting unknown  Fine without high winds
# 4        Darkness: street lighting unknown  Fine without high winds
#
#   Casualty Class Casualty Severity Sex of Casualty  Age of Casualty  \
# 0      Passenger            Slight          Female               20
# 1      Passenger            Slight            Male               39
# 2      Passenger            Slight          Female               25
# 3         Driver            Slight            Male               38
# 4         Driver            Slight            Male               42
#
#          Type of Vehicle
# 0                    Car
# 1  Taxi/Private hire car
# 2  Taxi/Private hire car
# 3                    Car
# 4                    Car

# %%
data_2011.shape
# Out:
# (2686, 15)

# %% [markdown]
# #### Data for 2012
# - No changes made, identical with base file (2009)

# %%
data_2012 = pd.read_csv("data/2012-6.csv",encoding='cp1252')

# %%
data_2012.head()
# Out:
#    Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0         120033394   430536    433129                   1     22-Jan-12
# 1         120034263   427301    434682                   2     23-Jan-12
# 2         120034970   422201    433910                   1     23-Jan-12
# 3         120035568   428891    431676                   1     24-Jan-12
# 4         120036061   442525    427843                   1     24-Jan-12
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0          255   Unclassified          Dry
# 1          800              A   Wet / Damp
# 2         1345              B          Dry
# 3          117   Unclassified   Wet / Damp
# 4          930   Unclassified          Dry
#
#                        Lighting Conditions          Weather Conditions  \
# 0        Darkness: street lighting unknown     Fine without high winds
# 1          Daylight: street lights present  Raining without high winds
# 2          Daylight: street lights present     Fine without high winds
# 3  Darkness: street lights present and lit     Fine without high winds
# 4          Daylight: street lights present     Fine without high winds
#
#   Casualty Class Casualty Severity Sex of Casualty  Age of Casualty  \
# 0     Pedestrian           Serious          Female               28
# 1         Driver            Slight            Male               19
# 2     Pedestrian           Serious          Female               73
# 3         Driver           Serious            Male               19
# 4     Pedestrian            Slight          Female               16
#
#                         Type of Vehicle
# 0                                   Car
# 1  Motorcycle over 50cc and up to 125cc
# 2                                   Car
# 3                                   Car
# 4  Motorcycle over 50cc and up to 125cc

# %%
data_2012.shape
# Out:
# (2748, 15)

# %% [markdown]
# #### Data for 2013
# - Some changes made, not identical with base file (2009)

# %%
data_2013 = pd.read_csv("data/2013-4.csv",encoding='cp1252')

# %%
data_2013.head()
# Out:
#   Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0        130021591   426983    433434                   3     15-Jan-13
# 1        130021629   424366    445442                   2     15-Jan-13
# 2        130021704   424481    435632                   2     13-Jan-13
# 3        130022047   430284    432421                   1     15-Jan-13
# 4        130023385   430374    433485                   1     16-Jan-13
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0         1545   Unclassified          Dry
# 1         1640              A  Frost / Ice
# 2         1345   Unclassified   Wet / Damp
# 3         1313   Unclassified          Dry
# 4         2015   Unclassified          Dry
#
#                        Lighting Conditions       Weather Conditions  \
# 0          Daylight: street lights present  Fine without high winds
# 1  Darkness: street lights present and lit                    Other
# 2          Daylight: street lights present  Fine without high winds
# 3          Daylight: street lights present  Fine without high winds
# 4  Darkness: street lights present and lit  Fine without high winds
#
#    Casualty Class Casualty Class.1 Casualty Severity Sex of Casualty  \
# 0               1           Driver            Slight            Male
# 1               2        Passenger            Slight          Female
# 2               1           Driver           Serious            Male
# 3               3       Pedestrian            Slight            Male
# 4               2        Passenger           Serious            Male
#
#    Age of Casualty                            Type of Vehicle
# 0               42                                        Car
# 1               78                                        Car
# 2               34      Motorcycle over 125cc and up to 500cc
# 3               47                                        Car
# 4               65  Bus or coach (17 or more passenger seats)

# %%
data_2013.shape
# Out:
# (2433, 16)

# %% [markdown]
# ##### Unbalanced column names  renaming  in data for 2013
# - Unnamed: 11 -> Casualty Class
# - Unnamed: 15 -> Type of Vehicle
# - Grid Ref: Easting -> Easting
# - Grid Ref: Northing ->Northing

# %%
data_2013=data_2013.rename({'Unnamed: 11':'Casualty Class','Unnamed: 15':'Type of Vehicle',
                            'Grid Ref: Easting':'Easting','Grid Ref: Northing':'Northing'},axis=1)

# %%
data_2013.columns
# Out:
# Index(['Reference Number', 'Easting', 'Northing', 'Number of Vehicles',
#        'Accident Date', 'Time (24hr)', '1st Road Class', 'Road Surface',
#        'Lighting Conditions', 'Weather Conditions', 'Casualty Class',
#        'Casualty Class.1', 'Casualty Severity', 'Sex of Casualty',
#        'Age of Casualty', 'Type of Vehicle'],
#       dtype='object')

# %%
data_2013.shape
# Out:
# (2433, 16)

# %% [markdown]
# #####  Saving changes back to csvfile 2013

# %%
data_2013.to_csv("data/2013-4.csv", index = False, header = True)

# %% [markdown]
# #### Data for 2014
# - Some changes made, not identical with base file (2009)

# %%
data_2014 = pd.read_csv("data/2014-11.csv",encoding='cp1252')

# %%
data_2014.head()
# Out:
#   Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0          1112091   429175    431904                   2     01-Jan-14
# 1          1180869   430429    431025                   3     08-Jan-14
# 2          1180869   430429    431025                   3     08-Jan-14
# 3          11A0238   424660    427582                   3     10-Jan-14
# 4          11A0238   424660    427582                   3     10-Jan-14
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0         1840   Unclassified   Wet / Damp
# 1         1430       Motorway   Wet / Damp
# 2         1430       Motorway   Wet / Damp
# 3          817       Motorway          Dry
# 4          817       Motorway          Dry
#
#                        Lighting Conditions          Weather Conditions  \
# 0  Darkness: street lights present and lit  Raining without high winds
# 1          Daylight: street lights present     Fine without high winds
# 2          Daylight: street lights present     Fine without high winds
# 3          Daylight: street lights present     Fine without high winds
# 4          Daylight: street lights present     Fine without high winds
#
#    Casualty Class Casualty Class.1 Casualty Severity Sex of Casualty  \
# 0               1           Driver            Slight            Male
# 1               1           Driver            Slight            Male
# 2               1           Driver            Slight          Female
# 3               1           Driver            Slight            Male
# 4               1           Driver            Slight            Male
#
#    Age of Casualty Type of Vehicle
# 0               58             Car
# 1               69             Car
# 2               41             Car
# 3               35             Car
# 4               25             Car

# %%
data_2014.shape
# Out:
# (2533, 16)

# %% [markdown]
# ##### Unbalanced column names  renaming  in data_2014
# - Grid Ref: Easting -> Easting
# - Grid Ref: Northing ->Northing

# %%
data_2014=data_2014.rename({'Unnamed: 11':'Casualty Class.1',
                            'Grid Ref: Easting':'Easting','Grid Ref: Northing':'Northing'},axis=1)

# %%
data_2014.head()
# Out:
#   Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0          1112091   429175    431904                   2     01-Jan-14
# 1          1180869   430429    431025                   3     08-Jan-14
# 2          1180869   430429    431025                   3     08-Jan-14
# 3          11A0238   424660    427582                   3     10-Jan-14
# 4          11A0238   424660    427582                   3     10-Jan-14
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0         1840   Unclassified   Wet / Damp
# 1         1430       Motorway   Wet / Damp
# 2         1430       Motorway   Wet / Damp
# 3          817       Motorway          Dry
# 4          817       Motorway          Dry
#
#                        Lighting Conditions          Weather Conditions  \
# 0  Darkness: street lights present and lit  Raining without high winds
# 1          Daylight: street lights present     Fine without high winds
# 2          Daylight: street lights present     Fine without high winds
# 3          Daylight: street lights present     Fine without high winds
# 4          Daylight: street lights present     Fine without high winds
#
#    Casualty Class Casualty Class.1 Casualty Severity Sex of Casualty  \
# 0               1           Driver            Slight            Male
# 1               1           Driver            Slight            Male
# 2               1           Driver            Slight          Female
# 3               1           Driver            Slight            Male
# 4               1           Driver            Slight            Male
#
#    Age of Casualty Type of Vehicle
# 0               58             Car
# 1               69             Car
# 2               41             Car
# 3               35             Car
# 4               25             Car

# %% [markdown]
# ##### Saving changes back to csvfile 2014

# %%
data_2014.to_csv("data/2014-11.csv", index = False, header = True)

# %%
data_2014 = pd.read_csv("data/2014-11.csv")
data_2014.head()
# Out:
#   Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0          1112091   429175    431904                   2     01-Jan-14
# 1          1180869   430429    431025                   3     08-Jan-14
# 2          1180869   430429    431025                   3     08-Jan-14
# 3          11A0238   424660    427582                   3     10-Jan-14
# 4          11A0238   424660    427582                   3     10-Jan-14
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0         1840   Unclassified   Wet / Damp
# 1         1430       Motorway   Wet / Damp
# 2         1430       Motorway   Wet / Damp
# 3          817       Motorway          Dry
# 4          817       Motorway          Dry
#
#                        Lighting Conditions          Weather Conditions  \
# 0  Darkness: street lights present and lit  Raining without high winds
# 1          Daylight: street lights present     Fine without high winds
# 2          Daylight: street lights present     Fine without high winds
# 3          Daylight: street lights present     Fine without high winds
# 4          Daylight: street lights present     Fine without high winds
#
#    Casualty Class Casualty Class.1 Casualty Severity Sex of Casualty  \
# 0               1           Driver            Slight            Male
# 1               1           Driver            Slight            Male
# 2               1           Driver            Slight          Female
# 3               1           Driver            Slight            Male
# 4               1           Driver            Slight            Male
#
#    Age of Casualty Type of Vehicle
# 0               58             Car
# 1               69             Car
# 2               41             Car
# 3               35             Car
# 4               25             Car

# %% [markdown]
# #### Data for 2015
# - Some changes made, not identical with base file (2009)

# %%
data_2015 = pd.read_csv("data/2015-10.csv",encoding='cp1252')
data_2015.head()
# Out:
#   Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0          21G0539   427798    426248                   5     16-Jan-15
# 1          21G0539   427798    426248                   5     16-Jan-15
# 2          21G1108   431142    430087                   1     16-Jan-15
# 3          21H0565   434602    436699                   2     17-Jan-15
# 4          21H0638   434254    434318                   2     17-Jan-15
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0         1205              A         Snow
# 1         1205              A         Snow
# 2         1732   Unclassified   Wet / Damp
# 3          930   Unclassified          Dry
# 4         1315              A   Wet / Damp
#
#                        Lighting Conditions          Weather Conditions  \
# 0          Daylight: street lights present  Snowing without high winds
# 1          Daylight: street lights present  Snowing without high winds
# 2  Darkness: street lights present and lit     Fine without high winds
# 3          Daylight: street lights present     Fine without high winds
# 4          Daylight: street lights present     Fine without high winds
#
#   Casualty Class Casualty Severity Sex of Casualty  Age of Casualty  \
# 0   Driver/Rider            Slight            Male               36
# 1      Passenger            Slight            Male               27
# 2     Pedestrian           Serious            Male               68
# 3   Driver/Rider            Slight            Male               49
# 4   Driver/Rider            Slight            Male               33
#
#                           Type of Vehicle
# 0  Goods vehicle 3.5 tonnes mgw and under
# 1  Goods vehicle 3.5 tonnes mgw and under
# 2                                     Car
# 3                                     Car
# 4                                     Car

# %% [markdown]
# ##### Unbalanced column names  renaming  in data_2015
# - Grid Ref: Easting -> Easting
# - Grid Ref: Northing ->Northing

# %%
data_2015=data_2015.rename({'Grid Ref: Easting':'Easting','Grid Ref: Northing':'Northing'},axis=1)

# %% [markdown]
# #####  Saving changes back to csvfile 2015

# %%
data_2015.to_csv("data/2015-10.csv", index = False, header = True)
data_2015 = pd.read_csv("data/2015-10.csv")
data_2015.head()
# Out:
#   Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0          21G0539   427798    426248                   5     16-Jan-15
# 1          21G0539   427798    426248                   5     16-Jan-15
# 2          21G1108   431142    430087                   1     16-Jan-15
# 3          21H0565   434602    436699                   2     17-Jan-15
# 4          21H0638   434254    434318                   2     17-Jan-15
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0         1205              A         Snow
# 1         1205              A         Snow
# 2         1732   Unclassified   Wet / Damp
# 3          930   Unclassified          Dry
# 4         1315              A   Wet / Damp
#
#                        Lighting Conditions          Weather Conditions  \
# 0          Daylight: street lights present  Snowing without high winds
# 1          Daylight: street lights present  Snowing without high winds
# 2  Darkness: street lights present and lit     Fine without high winds
# 3          Daylight: street lights present     Fine without high winds
# 4          Daylight: street lights present     Fine without high winds
#
#   Casualty Class Casualty Severity Sex of Casualty  Age of Casualty  \
# 0   Driver/Rider            Slight            Male               36
# 1      Passenger            Slight            Male               27
# 2     Pedestrian           Serious            Male               68
# 3   Driver/Rider            Slight            Male               49
# 4   Driver/Rider            Slight            Male               33
#
#                           Type of Vehicle
# 0  Goods vehicle 3.5 tonnes mgw and under
# 1  Goods vehicle 3.5 tonnes mgw and under
# 2                                     Car
# 3                                     Car
# 4                                     Car

# %% [markdown]
# #### Data for 2016
# - Some changes made, not identical with base file (2009)

# %%
data_2016 = pd.read_csv("data/2016-7.csv",encoding='cp1252')
data_2016.head()
# Out:
#   Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0          2181280   418241    442351                   2    08/01/2016
# 1          2191037   424993    432898                   2    09/01/2016
# 2          2CQ0870   431159    436397                   2    15/01/2016
# 3          2CQ0870   431159    436397                   2    15/01/2016
# 4          3111091   439313    432376                   2    01/01/2016
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0         1905              A          Dry
# 1         1615   Unclassified          Dry
# 2         1645   Unclassified          Dry
# 3         1645   Unclassified          Dry
# 4          956              A   Wet / Damp
#
#                        Lighting Conditions       Weather Conditions  \
# 0  Darkness: street lights present and lit  Fine without high winds
# 1  Darkness: street lights present and lit  Fine without high winds
# 2          Daylight: street lights present  Fine without high winds
# 3          Daylight: street lights present  Fine without high winds
# 4          Daylight: street lights present  Fine without high winds
#
#                  Casualty Class Casualty Severity Sex of Casualty  \
# 0               Driver or rider           Serious            Male
# 1               Driver or rider            Slight          Female
# 2               Driver or rider            Slight            Male
# 3  Vehicle or pillion passenger            Slight          Female
# 4               Driver or rider            Slight            Male
#
#    Age of Casualty        Type of Vehicle
# 0               38  Motorcycle over 500cc
# 1               50                    Car
# 2               26                    Car
# 3               22                    Car
# 4               57            Pedal cycle

# %%
data_2016.shape
# Out:
# (2549, 15)

# %% [markdown]
# ##### Expr1 is dropped because this feature not available in other year's dataset

# %%
data_2016=data_2016.drop("Expr1",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-42558a2fa6fe> in <module>
# ----> 1 data_2016=data_2016.drop("Expr1",axis=1)
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5590         if mask.any():
#    5591             if errors != "ignore":
# -> 5592                 raise KeyError(f"{labels[mask]} not found in axis")
#    5593             indexer = indexer[~mask]
#    5594         return self.delete(indexer)
#
# KeyError: "['Expr1'] not found in axis"

# %% [markdown]
# ##### Unbalanced column names  renaming  in data_2016
#
# - Grid Ref: Easting -> Easting
# - Grid Ref: Northing ->Northing

# %%
data_2016=data_2016.rename({'Grid Ref: Easting':'Easting','Grid Ref: Northing':'Northing'},axis=1)

# %% [markdown]
# ##### Saving changes back to csvfile 2016

# %%
data_2016.to_csv("data/2016-7.csv", index = False, header = True)

# %% [markdown]
# #### Data for 2017
# - Some changes made, not identical with base file (2009)

# %%
data_2017 = pd.read_csv("data/2017-8.csv",encoding='cp1252')
data_2017.head()
# Out:
#   Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0          3AP0313   426340    428455                   1     3/17/2017
# 1          3BE0850   430828    433222                   2     1/14/2017
# 2          4110858   428940    429856                   2      1/1/2017
# 3          4110858   428940    429856                   2      1/1/2017
# 4          4111495   429899    434277                   2      1/1/2017
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0          815           A643          Dry
# 1         1330            A61          Dry
# 2          805           A653     Wet/Damp
# 3          805           A653     Wet/Damp
# 4         1705              U     Wet/Damp
#
#                        Lighting Conditions          Weather Conditions  \
# 0          Daylight: Street lights present                       Other
# 1          Daylight: Street lights present     Fine without high winds
# 2          Daylight: Street lights present     Fine without high winds
# 3          Daylight: Street lights present     Fine without high winds
# 4  Darkness: Street lights present and lit  Raining without high winds
#
#   Type of Vehicle                Casualty Class Casualty Severity  \
# 0             Car                    Pedestrian           Serious
# 1     Pedal cycle               Driver or rider            Slight
# 2             Car               Driver or rider            Slight
# 3             Car               Driver or rider            Slight
# 4             Car  Vehicle or pillion passenger            Slight
#
#   Sex of Casualty  Age of Casualty
# 0          Female               61
# 1            Male               36
# 2            Male               32
# 3            Male               30
# 4          Female               26

# %% [markdown]
# ##### Unbalanced column names renaming in data_2017
# - Grid Ref: Easting -> Easting
# - Grid Ref: Northing ->Northing

# %%
data_2017=data_2017.rename({'Grid Ref: Easting':'Easting','Grid Ref: Northing':'Northing','1st Road Class & No':'1st Road Class'},axis=1)

# %% [markdown]
# ##### Saving changes back to csvfile 2017

# %%
data_2017.to_csv("data/2017-8.csv",index = False, header = True)
data_2017.head()
# Out:
#   Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0          3AP0313   426340    428455                   1     3/17/2017
# 1          3BE0850   430828    433222                   2     1/14/2017
# 2          4110858   428940    429856                   2      1/1/2017
# 3          4110858   428940    429856                   2      1/1/2017
# 4          4111495   429899    434277                   2      1/1/2017
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0          815           A643          Dry
# 1         1330            A61          Dry
# 2          805           A653     Wet/Damp
# 3          805           A653     Wet/Damp
# 4         1705              U     Wet/Damp
#
#                        Lighting Conditions          Weather Conditions  \
# 0          Daylight: Street lights present                       Other
# 1          Daylight: Street lights present     Fine without high winds
# 2          Daylight: Street lights present     Fine without high winds
# 3          Daylight: Street lights present     Fine without high winds
# 4  Darkness: Street lights present and lit  Raining without high winds
#
#   Type of Vehicle                Casualty Class Casualty Severity  \
# 0             Car                    Pedestrian           Serious
# 1     Pedal cycle               Driver or rider            Slight
# 2             Car               Driver or rider            Slight
# 3             Car               Driver or rider            Slight
# 4             Car  Vehicle or pillion passenger            Slight
#
#   Sex of Casualty  Age of Casualty
# 0          Female               61
# 1            Male               36
# 2            Male               32
# 3            Male               30
# 4          Female               26

# %% [markdown]
# #### Data for 2018
# - Some changes made, not identical with base file (2009)

# %%
data_2018 = pd.read_csv("data/2018-5.csv",encoding='cp1252')
data_2018.head()
# Out:
#   Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0          51B0230   433936    428874                   1    11/01/2018
# 1          51B0349   430076    433872                   1    11/01/2018
# 2          51B0349   430076    433872                   1    11/01/2018
# 3          51B0349   430076    433872                   1    11/01/2018
# 4          51B0349   430076    433872                   1    11/01/2018
#
#    Time (24hr) 1st Road Class  Road Surface  Lighting Conditions  \
# 0          700              U             1                    4
# 1          855              U             2                    1
# 2          855              U             2                    1
# 3          855              U             2                    1
# 4          855              U             2                    1
#
#    Weather Conditions  Type of Vehicle  Casualty Class  Casualty Severity  \
# 0                   1                9               3                  3
# 1                   1               11               2                  3
# 2                   1               11               2                  3
# 3                   1               11               2                  3
# 4                   1               11               2                  3
#
#    Sex of Casualty  Age of Casualty
# 0                2               87
# 1                2               60
# 2                2               51
# 3                2               50
# 4                2               51

# %% [markdown]
# #####  Deletion of columns from data_2018
# The following columns are dropped to avoid discrepencies :
# - 1st Road Class,Local Authority
# - Vehicle Fields_Reference Number
# - Vehicle Number,Casualty Fields_Reference Number
# - Casualty Veh No

# %%
data_2018=data_2018.drop(["1st Road Class","Local Authority","Vehicle Fields_Reference Number","Vehicle Number","Casualty Fields_Reference Number","Casualty Veh No"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-0b44e94f5597> in <module>
# ----> 1 data_2018=data_2018.drop(["1st Road Class","Local Authority","Vehicle Fields_Reference Number","Vehicle Number","Casualty Fields_Reference Number","Casualty Veh No"], axis=1)
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5590         if mask.any():
#    5591             if errors != "ignore":
# -> 5592                 raise KeyError(f"{labels[mask]} not found in axis")
#    5593             indexer = indexer[~mask]
#    5594         return self.delete(indexer)
#
# KeyError: "['Local Authority' 'Vehicle Fields_Reference Number' 'Vehicle Number'\n 'Casualty Fields_Reference Number' 'Casualty Veh No'] not found in axis"

# %% [markdown]
# ##### Unbalanced column names renaming in data_2018
# - Accident Fields_Reference Number -> Reference Number
# - Grid Ref: Easting -> Easting
# - Grid Ref: Northing ->Northing
# - 1st Road Class & No1st ->  Road Class

# %%
data_2018=data_2018.rename({'Accident Fields_Reference Number':'Reference Number','Grid Ref: Easting':'Easting','Grid Ref: Northing':'Northing','1st Road Class & No':'1st Road Class'},axis=1)

# %% [markdown]
# ##### Saving changes back to csvfile 2018

# %%
data_2018.to_csv("data/2018-5.csv", index = False, header = True)

# %%
data_2018 = pd.read_csv("data//2018-5.csv")
data_2018.head()
# Out:
#   Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0          51B0230   433936    428874                   1    11/01/2018
# 1          51B0349   430076    433872                   1    11/01/2018
# 2          51B0349   430076    433872                   1    11/01/2018
# 3          51B0349   430076    433872                   1    11/01/2018
# 4          51B0349   430076    433872                   1    11/01/2018
#
#    Time (24hr) 1st Road Class  Road Surface  Lighting Conditions  \
# 0          700              U             1                    4
# 1          855              U             2                    1
# 2          855              U             2                    1
# 3          855              U             2                    1
# 4          855              U             2                    1
#
#    Weather Conditions  Type of Vehicle  Casualty Class  Casualty Severity  \
# 0                   1                9               3                  3
# 1                   1               11               2                  3
# 2                   1               11               2                  3
# 3                   1               11               2                  3
# 4                   1               11               2                  3
#
#    Sex of Casualty  Age of Casualty
# 0                2               87
# 1                2               60
# 2                2               51
# 3                2               50
# 4                2               51

# %% [markdown]
# ### Reading all  the cleaned csvfiles and Merging
# - __Here we used glob library to read all csvfile.__
#
# - __The glob(short for global) module is to return all file paths that match a specific pattern.__

# %%
# the path to  csv file directory
mycsvdir = 'data'

# get all the csv files in that directory (assuming they have the extension .csv)
csvfiles = glob.glob(os.path.join(mycsvdir, '2*.csv')) # every csv file starting with "2... in the name"

# loop through the files and read them in with pandas
dataframes = []  # a list to hold all the individual pandas DataFrames
for csvfile in csvfiles:
    df = pd.read_csv(csvfile,low_memory=False,encoding='cp1252') # for windows using cp1252 instead of utf-8
    dataframes.append(df)

# concatenate them all together
data = pd.concat(dataframes, ignore_index=True)

# %%
data.head()
# Out:
#   Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0             3309   429093    436258                   1     01-Jan-09
# 1             2609   434723    435534                   1     02-Jan-09
# 2             2809   441173    433047                   1     02-Jan-09
# 3             3809   428487    431364                   1     02-Jan-09
# 4             3909   425928    435480                   2     02-Jan-09
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0           55   Unclassified          Dry
# 1         2335   Unclassified          Dry
# 2         1645   Unclassified          Dry
# 3         1723              A          Dry
# 4         1350   Unclassified          Dry
#
#                        Lighting Conditions       Weather Conditions  \
# 0  Darkness: street lights present and lit  Fine without high winds
# 1  Darkness: street lights present and lit  Fine without high winds
# 2  Darkness: street lights present and lit  Fine without high winds
# 3  Darkness: street lights present and lit  Fine without high winds
# 4          Daylight: street lights present  Fine without high winds
#
#   Casualty Class Casualty Severity Sex of Casualty  Age of Casualty  \
# 0     Pedestrian            Slight            Male               44
# 1         Driver           Serious          Female               23
# 2     Pedestrian            Slight          Female               12
# 3     Pedestrian            Slight            Male               15
# 4         Driver            Slight          Female               34
#
#   Type of Vehicle Casualty Class.1
# 0             Car              NaN
# 1             Car              NaN
# 2             Car              NaN
# 3             Car              NaN
# 4             Car              NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25633 entries, 0 to 25632
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Reference Number     25633 non-null  object
#  1   Easting              25633 non-null  int64
#  2   Northing             25633 non-null  int64
#  3   Number of Vehicles   25633 non-null  int64
#  4   Accident Date        25633 non-null  object
#  5   Time (24hr)          25633 non-null  int64
#  6   1st Road Class       25633 non-null  object
#  7   Road Surface         25632 non-null  object
#  8   Lighting Conditions  25633 non-null  object
#  9   Weather Conditions   25633 non-null  object
#  10  Type of Vehicle      25632 non-null  object
#  11  Casualty Class       25633 non-null  object
#  12  Casualty Severity    25633 non-null  object
#  13  Sex of Casualty      25633 non-null  object
#  14  Age of Casualty      25633 non-null  int64
#  15  Casualty Class.1     4966 non-null   object
# dtypes: int64(5), object(11)
# memory usage: 3.1+ MB

# %% [markdown]
# #### Dropping Duplicate column
# - Casualty Class.1 is dropped

# %%
data= data.drop("Casualty Class.1",axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25633 entries, 0 to 25632
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Reference Number     25633 non-null  object
#  1   Easting              25633 non-null  int64
#  2   Northing             25633 non-null  int64
#  3   Number of Vehicles   25633 non-null  int64
#  4   Accident Date        25633 non-null  object
#  5   Time (24hr)          25633 non-null  int64
#  6   1st Road Class       25633 non-null  object
#  7   Road Surface         25632 non-null  object
#  8   Lighting Conditions  25633 non-null  object
#  9   Weather Conditions   25633 non-null  object
#  10  Type of Vehicle      25632 non-null  object
#  11  Casualty Class       25633 non-null  object
#  12  Casualty Severity    25633 non-null  object
#  13  Sex of Casualty      25633 non-null  object
#  14  Age of Casualty      25633 non-null  int64
# dtypes: int64(5), object(10)
# memory usage: 2.9+ MB

# %% [markdown]
# ### Reading guidelines csv file conatianing mapping data to group dataset values

# %%
guidance_data= pd.read_csv('data/guidance.csv',encoding='cp1252')

# %%
guidance_data.head(10)
# Out:
#   1st Road Class 1st Road Class Desc
# 0              1            Motorway
# 1              2                A(M)
# 2              3                   A
# 3              4                   B
# 4              5                   C
# 5              6        Unclassified
# 6            NaN                 NaN
# 7   Road Surface   Road Surface Desc
# 8              1                 Dry
# 9              2          Wet / Damp

# %% [markdown]
# ####  Road Class Data mapping

# %%
dict_road = dict(zip(guidance_data.loc[0:5]['1st Road Class'].values,guidance_data.loc[0:5]['1st Road Class Desc'].values))
dict_road
# Out:
# {'1': 'Motorway',
#  '2': 'A(M)',
#  '3': 'A',
#  '4': 'B',
#  '5': 'C',
#  '6': 'Unclassified'}

# %%
data['1st Road Class'] = data['1st Road Class'].replace(dict_road)
data['1st Road Class'].unique()
# Out:
# array(['Unclassified', 'A', 'A(M)', 'B', 'Motorway', 'C', 'A643', 'A61',
#        'A653', 'U', 'M1', 'A650', 'A58', 'A65', 'B6123', 'A660', 'M62',
#        'A658', 'M621', 'A58(M)', 'A647', 'A657', 'B6159', 'B6157',
#        'A1(M)', 'A639', 'B1271', 'A63', 'A654', 'A168', 'B6135', 'A6210',
#        'A6110', 'A6120', 'A64', 'B6154', 'A62', 'A656', 'B6156', 'A642',
#        'B6152', 'B6129', 'B1217', 'B6137', 'A659', 'B6451', 'B6153',
#        'B6127', 'A6038', 'B6128', 'B6164', 'B1224', 'A64(M)', 'B1',
#        'B6126', 'B6155', 'B6381', 'A1', 'B6481', 'B1222', 'A661', 'A664',
#        'A54', 'A635'], dtype=object)

# %%
data['1st Road Class']=data['1st Road Class'].replace(to_replace=[r'A.*',r'B.*',r'U.*',r'M.*'],value=[r'A',r'B',r'Unclassified',r'Motorway'],regex=True)
data['1st Road Class'].unique()
# Out:
# array(['Unclassified', 'A', 'B', 'Motorway', 'C'], dtype=object)

# %% [markdown]
# #### Road Surface data mapping

# %%
dict_road_surface = dict(zip(guidance_data.loc[8:12]['1st Road Class'].values,guidance_data.loc[8:12]['1st Road Class Desc'].values))
dict_road_surface
# Out:
# {'1': 'Dry',
#  '2': 'Wet / Damp',
#  '3': 'Snow',
#  '4': 'Frost / Ice',
#  '5': 'Flood (surface water over 3cm deep)'}

# %% [markdown]
# ####

# %%
# replaceing the Road Surface entities
data['Road Surface'] = data['Road Surface'].astype(str).replace(dict_road_surface)
# removing the empty space between the data
data['Road Surface']=[i.replace(' ','') for i in data['Road Surface']]
data["Road Surface"] = data["Road Surface"].replace(to_replace=r'Flood(surfacewaterover3cmdeep)',value="Flood")

data['Road Surface'].unique()
# Out:
# array(['Dry', 'Wet/Damp', 'Frost/Ice', 'Snow', 'Flood', 'nan'],
#       dtype=object)

# %% [markdown]
# #### Lighting conditions data mapping

# %%
dict_lightning = dict(zip(guidance_data.loc[15:21]['1st Road Class'].values,guidance_data.loc[15:21]['1st Road Class Desc'].values))
dict_lightning
# Out:
# {'1': 'Daylight: street lights present',
#  '2': 'Daylight: no street lighting',
#  '3': 'Daylight: street lighting unknown',
#  '4': 'Darkness: street lights present and lit',
#  '5': 'Darkness: street lights present but unlit',
#  '6': 'Darkness: no street lighting',
#  '7': 'Darkness: street lighting unknown'}

# %%
#replacing the Lighting Conditions entities
data['Lighting Conditions'] = data['Lighting Conditions'].astype(str).replace(dict_lightning)

data['Lighting Conditions'].unique()
# data['Lighting Conditions'].repalce()
# Out:
# array(['Darkness: street lights present and lit',
#        'Daylight: street lights present', 'Darkness: no street lighting',
#        'Darkness: street lighting unknown',
#        'Darkness: street lights present but unlit',
#        'Daylight: Street lights present',
#        'Darkness: Street lights present and lit',
#        'Darkness: No street lighting',
#        'Darkness: Street lighting unknown',
#        'Darkness: Street lights present but unlit',
#        'Darkness: Street lights present and lit and lit'], dtype=object)

# %%
# for grouping  uniformly  decided  to rpleace
#darkness: street lights present and lit and lit':'darkness: street lights present and lit'
data['Lighting Conditions']=[i.lower() for i in data['Lighting Conditions']]
data['Lighting Conditions'] = data['Lighting Conditions'].replace({'darkness: street lights present and lit and lit':'darkness'': street lights present and lit'})
data['Lighting Conditions'].unique()
# Out:
# array(['darkness: street lights present and lit',
#        'daylight: street lights present', 'darkness: no street lighting',
#        'darkness: street lighting unknown',
#        'darkness: street lights present but unlit'], dtype=object)

# %% [markdown]
# #### Weather Conditions data mapping

# %%
dict_weather = dict(zip(guidance_data.loc[24:32]['1st Road Class'].values,guidance_data.loc[24:32]['1st Road Class Desc'].values))
dict_weather
# Out:
# {'1': 'Fine without high winds',
#  '2': 'Raining without high winds',
#  '3': 'Snowing without high winds',
#  '4': 'Fine with high winds',
#  '5': 'Raining with high winds',
#  '6': 'Snowing with high winds',
#  '7': 'Fog or mist – if hazard',
#  '8': 'Other',
#  '9': 'Unknown'}

# %%
#replacing Weather Conditions entities
data['Weather Conditions'] = data['Weather Conditions'].astype(str).replace(dict_weather)
data['Weather Conditions'].unique()

# %%
data['Weather Conditions']=data['Weather Conditions'].replace(to_replace=r'Fog or mist.*',value='Fog or mist',regex=True)

data['Weather Conditions'].unique()
# Out:
# array(['Fine without high winds', 'Other', 'Raining without high winds',
#        'Raining with high winds', 'Snowing without high winds', 'Unknown',
#        'Fog or mist', 'Fine with high winds', 'Snowing with high winds',
#        'Darkness: street lighting unknown'], dtype=object)

# %% [markdown]
# #### Casualty Class data mapping

# %%
dict_casualty_class = dict(zip(guidance_data.loc[35:37]['1st Road Class'].values,guidance_data.loc[35:37]['1st Road Class Desc'].values))
dict_casualty_class
# Out:
# {'1': 'Driver or rider',
#  '2': 'Vehicle or pillion passenger',
#  '3': 'Pedestrian'}

# %%
# Replacing Casualty CLass entites
data['Casualty Class']=data['Casualty Class']=data['Casualty Class'].astype(str).replace(dict_casualty_class)
data['Casualty Class']= data['Casualty Class'].replace({'Driver':'Driver/Rider','Driver or rider':'Driver/Rider','Vehicle or pillion passenger':'Passenger'})
data['Casualty Class'].unique()
# Out:
# array(['Pedestrian', 'Driver/Rider', 'Passenger'], dtype=object)

# %% [markdown]
# #### Casualty Serverity Data Mapping

# %%
dict_casualty_severity = dict(zip(guidance_data.loc[40:42]['1st Road Class'].values,guidance_data.loc[40:42]['1st Road Class Desc'].values))
dict_casualty_severity
# Out:
# {'1': 'Fatal', '2': 'Serious', '3': 'Slight'}

# %%
#Replacing Casulty Severity entities
data['Casualty Severity']=data['Casualty Severity'].astype(str).replace(dict_casualty_severity)
data['Casualty Severity'].unique()
# Out:
# array(['Slight', 'Serious', 'Fatal'], dtype=object)

# %% [markdown]
# #### Sex of Casualty Data Mapping

# %%
#### Here creating dictionary by taking the index values by using loc for sex of Casualty 
dict_casualty_sex = dict(zip(guidance_data.loc[45:46]['1st Road Class'].values,guidance_data.loc[45:46]['1st Road Class Desc'].values))
dict_casualty_sex
# Out:
# {'1': 'Male', '2': 'Female'}

# %%
#replacing Sex of Casualty entities
data['Sex of Casualty']=data['Sex of Casualty'].astype(str).replace(dict_casualty_sex)
data['Sex of Casualty'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# #### Type of Vehicle Data Mapping

# %%
#### Here creating dictionary by taking the index values by using loc for Type of Vehicle
dict_type_vehc = dict(zip(guidance_data.loc[52:]['1st Road Class'].values,guidance_data.loc[52:]['1st Road Class Desc'].values))
dict_type_vehc
# Out:
# {'1': 'Pedal cycle',
#  '2': 'M/cycle 50cc and under',
#  '3': 'Motorcycle over 50cc and up to 125cc',
#  '4': 'Motorcycle over 125cc and up to 500cc',
#  '5': 'Motorcycle over 500cc',
#  '6': '[Not used]',
#  '7': '[Not used]',
#  '8': 'Taxi/Private hire car',
#  '9': 'Car',
#  '10': 'Minibus (8 – 16 passenger seats)',
#  '11': 'Bus or coach (17 or more passenger seats)',
#  '12': '[Not used]',
#  '13': '[Not used]',
#  '14': 'Other motor vehicle',
#  '15': 'Other non-motor vehicle',
#  '16': 'Ridden horse',
#  '17': 'Agricultural vehicle (includes diggers etc.)',
#  '18': 'Tram / Light rail',
#  '19': 'Goods vehicle 3.5 tonnes mgw and under',
#  '20': 'Goods vehicle over 3.5 tonnes and under 7.5 tonnes mgw',
#  '21': 'Goods vehicle 7.5 tonnes mgw and over',
#  '22': 'Mobility Scooter',
#  '90': 'Other Vehicle ',
#  '97': 'Motorcycle - Unknown CC'}

# %%
#Replacing Type of Vehicle entities
data['Type of Vehicle']=data['Type of Vehicle'].astype(str).replace(dict_type_vehc)
data['Type of Vehicle'].unique()
a= data['Type of Vehicle']
a.unique()

# %% [markdown]
# #### Grouping the vehicle types for uniformity
# Used regular expression to replace the vehicle type names:
# - All names start with Motorcycle or M/cycle -> Motorclycle
# - All names start with Minibus -> minibus
# - All names start with Bus -> Bus.
# - All names start with Tax -> Taxi/Hire
# - All names start with Goods -> Goods Vehicle
# - Pedal names start with -> Pedal cycle
# - All names start with Car -> Car

# %%
data['Type of Vehicle']=data['Type of Vehicle'].replace(to_replace=r'Motorcy.*',value="Motorcycle",regex=True)

# %%
data['Type of Vehicle']=data['Type of Vehicle'].replace(to_replace=r'M/cycle.*',value="Motorcycle",regex=True)

# %%
data['Type of Vehicle']=data['Type of Vehicle'].replace(to_replace=r'Bus.*',value="Bus",regex=True)

# %%
data['Type of Vehicle']=data['Type of Vehicle'].replace(to_replace=r'Taxi.*',value="Taxi/Hire",regex=True)

# %%
data['Type of Vehicle']=data['Type of Vehicle'].replace(to_replace=r'Goods.*',value="Goods Vehicle",regex=True)

# %%
data['Type of Vehicle']=data['Type of Vehicle'].replace(to_replace=r'Pedal.*',value="Pedal cycle",regex=True)

# %%
data['Type of Vehicle']=data['Type of Vehicle'].replace(to_replace=r'Car.*',value="Car",regex=True)

# %%
data['Type of Vehicle']=data['Type of Vehicle'].replace(to_replace=r'Minibus.*',value="Minibus",regex=True)

# %%
data["Type of Vehicle"].unique()
# Out:
# array(['Car', 'Bus', 'Taxi/Hire', 'Motorcycle', 'Pedal cycle',
#        'Other Vehicle ', 'Goods Vehicle', 'Minibus',
#        'Agricultural vehicle (includes diggers etc.)', 'Ridden horse',
#        'Mobility Scooter', 'Tram / Light rail', 'nan'], dtype=object)

# %% [markdown]
# #### Grouping the Age of Casualty
#
# age group as follows:
# - 0-14 years (children)
# - 15-24 years (early working age)
# - 25-54 years (prime working age)
# - 55-64 years (mature working age)
# - 65 years and over (elderly)

# %%
def age_group(x):
    if x in range(1,15):
        return "children"
    elif x in range(15,25):
        return "early working age"
    elif x in range(25,55):
        return "prime working age"
    elif x in range(55,65):
        return "mature working age"
    elif x > 65:
        return "elderly"
    else:
        return "nan"

# %%
data['Age of Casualty'] = data['Age of Casualty'].apply(age_group)

# %%
data['Age of Casualty'].unique()
# Out:
# array(['prime working age', 'early working age', 'children',
#        'mature working age', 'elderly', 'nan'], dtype=object)

# %%
data.columns
# Out:
# Index(['Reference Number', 'Easting', 'Northing', 'Number of Vehicles',
#        'Accident Date', 'Time (24hr)', '1st Road Class', 'Road Surface',
#        'Lighting Conditions', 'Weather Conditions', 'Casualty Class',
#        'Casualty Severity', 'Sex of Casualty', 'Age of Casualty',
#        'Type of Vehicle', 'Casualty Class.1'],
#       dtype='object')

# %% [markdown]
# ##### Setting datetime as index

# %%
data['Time (24hr)']=data['Time (24hr)'].astype(str).str.zfill(4)
data['Time (24hr)'].head()
# Out:
# 0    0055
# 1    2335
# 2    1645
# 3    1723
# 4    1350
# Name: Time (24hr), dtype: object

# %%
data['Datetime'] = pd.to_datetime(data['Accident Date'].astype(str) + ' ' + data['Time (24hr)'].astype(str))
data['Datetime'].head()
# Out:
# 0   2009-01-01 00:55:00
# 1   2009-01-02 23:35:00
# 2   2009-01-02 16:45:00
# 3   2009-01-02 17:23:00
# 4   2009-01-02 13:50:00
# Name: Datetime, dtype: datetime64[ns]

# %%
data=data.set_index('Datetime')
data=data.sort_index()

# %% [markdown]
# ##### dropping Accident Datetime' and Time (24hr) columns

# %%
data=data.drop(labels=['Accident Date', 'Time (24hr)'],axis=1)

# %%
data.shape
# Out:
# (25633, 14)

# %% [markdown]
# #### Saving to csv file of all cleaned and grouped data for further analysis

# %%
data.to_csv('data/final_cleaned.csv')

# %% [markdown]
# #### Loding cleaned csv file for further analysis

# %%
data= pd.read_csv("data/final_cleaned.csv",parse_dates=['Datetime'],index_col='Datetime')

# %%
data.head()
# Out:
#                     Reference Number  Easting  Northing  Number of Vehicles  \
# Datetime
# 2009-01-01 00:55:00             3309   429093    436258                   1
# 2009-01-02 13:50:00             3909   425928    435480                   2
# 2009-01-02 13:50:00             3909   425928    435480                   2
# 2009-01-02 16:45:00             2809   441173    433047                   1
# 2009-01-02 17:23:00             3809   428487    431364                   1
#
#                     1st Road Class Road Surface  \
# Datetime
# 2009-01-01 00:55:00   Unclassified          Dry
# 2009-01-02 13:50:00   Unclassified          Dry
# 2009-01-02 13:50:00   Unclassified          Dry
# 2009-01-02 16:45:00   Unclassified          Dry
# 2009-01-02 17:23:00              A          Dry
#
#                                          Lighting Conditions  \
# Datetime
# 2009-01-01 00:55:00  darkness: street lights present and lit
# 2009-01-02 13:50:00          daylight: street lights present
# 2009-01-02 13:50:00          daylight: street lights present
# 2009-01-02 16:45:00  darkness: street lights present and lit
# 2009-01-02 17:23:00  darkness: street lights present and lit
#
#                           Weather Conditions Casualty Class Casualty Severity  \
# Datetime
# 2009-01-01 00:55:00  Fine without high winds     Pedestrian            Slight
# 2009-01-02 13:50:00  Fine without high winds   Driver/Rider            Slight
# 2009-01-02 13:50:00  Fine without high winds   Driver/Rider            Slight
# 2009-01-02 16:45:00  Fine without high winds     Pedestrian            Slight
# 2009-01-02 17:23:00  Fine without high winds     Pedestrian            Slight
#
#                     Sex of Casualty    Age of Casualty Type of Vehicle  \
# Datetime
# 2009-01-01 00:55:00            Male  prime working age             Car
# 2009-01-02 13:50:00          Female  prime working age             Car
# 2009-01-02 13:50:00            Male  prime working age             Car
# 2009-01-02 16:45:00          Female           children             Car
# 2009-01-02 17:23:00            Male  early working age             Car
#
#                     Casualty Class.1
# Datetime
# 2009-01-01 00:55:00              NaN
# 2009-01-02 13:50:00              NaN
# 2009-01-02 13:50:00              NaN
# 2009-01-02 16:45:00              NaN
# 2009-01-02 17:23:00              NaN

# %%
data.index
# Out:
# DatetimeIndex(['2009-01-01 00:55:00', '2009-01-02 13:50:00',
#                '2009-01-02 13:50:00', '2009-01-02 16:45:00',
#                '2009-01-02 17:23:00', '2009-01-02 23:00:00',
#                '2009-01-02 23:35:00', '2009-01-03 02:22:00',
#                '2009-01-03 03:25:00', '2009-01-03 16:45:00',
#                ...
#                '2018-12-26 23:10:00', '2018-12-27 14:54:00',
#                '2018-12-30 07:25:00', '2018-12-30 09:45:00',
#                '2018-12-30 22:56:00', '2018-12-31 13:45:00',
#                '2018-12-31 13:45:00', '2018-12-31 13:45:00',
#                '2018-12-31 13:45:00', '2018-12-31 16:08:00'],
#               dtype='datetime64[ns]', name='Datetime', length=25633, freq=None)

# %% [markdown]
# #### Change columns names

# %%
# Replace spaces by underscores and upper case letters by lower case letters.
data.rename(columns=lambda x:x.replace(' ','_').lower(), inplace=True)

# %%
data.columns
# Out:
# Index(['reference_number', 'easting', 'northing', 'number_of_vehicles',
#        '1st_road_class', 'road_surface', 'lighting_conditions',
#        'weather_conditions', 'casualty_class', 'casualty_severity',
#        'sex_of_casualty', 'age_of_casualty', 'type_of_vehicle',
#        'casualty_class.1'],
#       dtype='object')

# %% [markdown]
# ### Data Analysis and Visualization

# %% [markdown]
# ####  Number of accident per year by type of vechicle

# %%
(data.groupby([data.index.year,data.type_of_vehicle]).type_of_vehicle.count()).unstack()
# Out:
# type_of_vehicle  Agricultural vehicle (includes diggers etc.)    Bus     Car  \
# Datetime
# 2009                                                      2.0  271.0  2093.0
# 2010                                                      NaN  186.0  1957.0
# 2011                                                      1.0  170.0  1865.0
# 2012                                                      2.0  180.0  1882.0
# 2013                                                      1.0  133.0  1642.0
# 2014                                                      NaN  147.0  1605.0
# 2015                                                      3.0  161.0  1727.0
# 2016                                                      NaN  109.0  1665.0
# 2017                                                      NaN    NaN  1446.0
# 2018                                                      NaN  127.0  1259.0
#
# type_of_vehicle  Goods Vehicle  Minibus  Mobility Scooter  Motorcycle  \
# Datetime
# 2009                      88.0     13.0               NaN       217.0
# 2010                      71.0     22.0               NaN       159.0
# 2011                      95.0     13.0               NaN       181.0
# 2012                      84.0     13.0               NaN       190.0
# 2013                      69.0      7.0               1.0       189.0
# 2014                     100.0      3.0               4.0       204.0
# 2015                     100.0     14.0               4.0       203.0
# 2016                      97.0      5.0               7.0       189.0
# 2017                       NaN      NaN               NaN       203.0
# 2018                      80.0      6.0               3.0       149.0
#
# type_of_vehicle  Other Vehicle   Pedal cycle  Ridden horse  Taxi/Hire  \
# Datetime
# 2009                       24.0        253.0           NaN       96.0
# 2010                       27.0        222.0           1.0      120.0
# 2011                       11.0        260.0           2.0       88.0
# 2012                       18.0        262.0           2.0      115.0
# 2013                        8.0        319.0           NaN       64.0
# 2014                       12.0        348.0           1.0      109.0
# 2015                       14.0        322.0           NaN      113.0
# 2016                        3.0        355.0           NaN      118.0
# 2017                        NaN        485.0           NaN       69.0
# 2018                        4.0        294.0           1.0       72.0
#
# type_of_vehicle  Tram / Light rail
# Datetime
# 2009                           NaN
# 2010                           NaN
# 2011                           NaN
# 2012                           NaN
# 2013                           NaN
# 2014                           NaN
# 2015                           3.0
# 2016                           NaN
# 2017                           NaN
# 2018                           NaN

# %%
vehicle_percent= (data.resample('Y')["type_of_vehicle"].value_counts(normalize=True)*100).sort_values(ascending=True).unstack()
vehicle_percent
# Out:
# type_of_vehicle  Agricultural vehicle (includes diggers etc.)       Bus  \
# Datetime
# 2009-12-31                                           0.065424  8.864900
# 2010-12-31                                                NaN  6.726944
# 2011-12-31                                           0.037230  6.329114
# 2012-12-31                                           0.072780  6.550218
# 2013-12-31                                           0.041102  5.466502
# 2014-12-31                                                NaN  5.803395
# 2015-12-31                                           0.112613  6.043544
# 2016-12-31                                                NaN  4.277865
# 2017-12-31                                                NaN       NaN
# 2018-12-31                                                NaN  6.365915
#
# type_of_vehicle        Car  Goods Vehicle   Minibus  Mobility Scooter  \
# Datetime
# 2009-12-31       68.465816       2.878639  0.425254               NaN
# 2010-12-31       70.777577       2.567812  0.795660               NaN
# 2011-12-31       69.434103       3.536858  0.483991               NaN
# 2012-12-31       68.486172       3.056769  0.473071               NaN
# 2013-12-31       67.488697       2.836005  0.287711          0.041102
# 2014-12-31       63.363600       3.947888  0.118437          0.157916
# 2015-12-31       64.827327       3.753754  0.525526          0.150150
# 2016-12-31       65.345369       3.806907  0.196232          0.274725
# 2017-12-31       65.637767            NaN       NaN               NaN
# 2018-12-31       63.107769       4.010025  0.300752          0.150376
#
# type_of_vehicle  Motorcycle  Other Vehicle   Pedal cycle  Ridden horse  \
# Datetime
# 2009-12-31         7.098463        0.785083     8.276088           NaN
# 2010-12-31         5.750452        0.976492     8.028933      0.036166
# 2011-12-31         6.738645        0.409531     9.679821      0.074460
# 2012-12-31         6.914119        0.655022     9.534207      0.072780
# 2013-12-31         7.768187        0.328812    13.111385           NaN
# 2014-12-31         8.053691        0.473747    13.738650      0.039479
# 2015-12-31         7.620120        0.525526    12.087087           NaN
# 2016-12-31         7.417582        0.117739    13.932496           NaN
# 2017-12-31         9.214707             NaN    22.015433           NaN
# 2018-12-31         7.468672        0.200501    14.736842      0.050125
#
# type_of_vehicle  Taxi/Hire  Tram / Light rail
# Datetime
# 2009-12-31        3.140334                NaN
# 2010-12-31        4.339964                NaN
# 2011-12-31        3.276247                NaN
# 2012-12-31        4.184862                NaN
# 2013-12-31        2.630497                NaN
# 2014-12-31        4.303198                NaN
# 2015-12-31        4.241742           0.112613
# 2016-12-31        4.631083                NaN
# 2017-12-31        3.132093                NaN
# 2018-12-31        3.609023                NaN

# %%
axes=vehicle_percent[['Car','Pedal cycle','Motorcycle']].plot(sharex=True,subplots=True,marker='o',
                                             title ="Yearly percentage of vechicles in vonvolved",
                                                         xlabel="year",
                                                         figsize = (10,8),
                                                         grid=True
                                                        );

plt.subplots_adjust(hspace=0.5) 
axes[0].set_ylabel('Car (%)');
axes[1].set_ylabel('Pedal Cycle (%)');
axes[2].set_ylabel('Motorcycle (%)');

# %% [markdown]
# - Car, Pedal cycle and Motorcycle have the highest percentage of involvment in accidents.
# - Car stands at the highest percentage, shows a downward trend over the years.
# - Pedal cycle and motorcycle show similar trend over the years, and the trend is upward untill 2017, and afterwards its showing downward trend.

# %% [markdown]
# #### Number of accident per year by Age of Casualty

# %%
age_percent = (data.resample('Y')["age_of_casualty"].value_counts(normalize=True)*100).sort_values(ascending=True).unstack()
age_percent.mean()
# Out:
# age_of_casualty
# children               9.333440
# early working age     24.146915
# elderly                7.631911
# mature working age     7.436307
# prime working age     51.451427
# dtype: float64

# %%
axes=age_percent.plot(kind="bar"#subplots=True,
                       #sharex=True,
                       #marker='d',
                       title ="Yearly percentage of age group in involved",
                       xlabel="year", 
                       figsize = (10,8),
                       grid=True
                        );

'''plt.subplots_adjust(hspace=1) 
axes[0].set_ylabel('Children (%)');
axes[1].set_ylabel('early working age (%)');
axes[2].set_ylabel('elderly (%)');
axes[3].set_ylabel('mature working age (%)');
axes[4].set_ylabel('prime working age (%)');
'''
# Out:
#   File "/tmp/ipykernel_216/468406564.py", line 4
#     title ="Yearly percentage of age group in involved",
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# - Highest accidents met by prime working age people for overall years.
# - Next  early working age people and followed by children,elderly and least mature working age.

# %% [markdown]
# #### Number of accident per year by Casualty Serverity

# %%
casualty_severity_percent= (data.resample('Y')["casualty_severity"].value_counts(normalize=True)*100).sort_values(ascending=True).unstack()
casualty_severity_percent.mean()
# Out:
# casualty_severity
# Fatal       0.738302
# Serious    11.881695
# Slight     87.380003
# dtype: float64

# %%
axes=casualty_severity_percent.plot(sharex=True,
                                subplots=True,
                                marker='o',
                                title ="Yearly percentage of casualty severity in involved",
                                xlabel="year",
                                figsize = (10,8),
                                grid=True
                                );
plt.subplots_adjust(hspace=0.1) 
axes[0].set_ylabel('Fatal (%)');
axes[1].set_ylabel('Serious (%)');
axes[2].set_ylabel('Slight (%)');

# %% [markdown]
# - Accidents Fetal is up and downs all the years maximum number Fetal happend in year 2018.
#
# - People met with accident and  condition is serious  increased by yearly and reached max in 2018.
#
# - People met with accident and  condition is standard standard for intial years and after continiously decreased.

# %% [markdown]
# #### Number of accident per year by Lighting Conditions

# %%
lighting_conditions=(data.resample('Y')["lighting_conditions"].value_counts(normalize=True)*100).sort_values(ascending=True).unstack()
lighting_conditions.mean()
# Out:
# lighting_conditions
# darkness: no street lighting                  1.883013
# darkness: street lighting unknown             7.465467
# darkness: street lights present and lit      21.620664
# darkness: street lights present but unlit     0.252832
# daylight: street lights present              68.778024
# dtype: float64

# %%
axes=lighting_conditions[['darkness: street lighting unknown',
'darkness: street lights present and lit',
'daylight: street lights present']].plot(sharex=True,
                         subplots=True,
                         marker='o',
                        title ="lighting conditions for accidents occure",
                        xlabel="year",
                        figsize = (10,10),
                        grid=True
                        );
plt.subplots_adjust(hspace=0.5) 

axes[0].set_ylabel('dark: str light known (%)');
axes[1].set_ylabel('dark:str light lit (%)');
axes[2].set_ylabel('day:streetlight present (%)');

# %% [markdown]
# - Most of the accidents happend daylight street lights present, darkness: street lights present and lit and darkness: street lighting unknown

# %% [markdown]
# #### Number of accident per year by Weather Conditions

# %%
weather_conditions_percent=(data.resample('Y')["weather_conditions"].value_counts(normalize=True)*100).sort_values(ascending=True).unstack()
mean_values=weather_conditions_percent.mean().sort_values(ascending=False)
print('Max Accidents occur during:\n',mean_values.nlargest(2))

mean_values
# Out:
# Max Accidents occur during:
#  weather_conditions
# Fine without high winds       86.18916
# Raining without high winds     8.50639
# dtype: float64
# weather_conditions
# Fine without high winds              86.189160
# Raining without high winds            8.506390
# Unknown                               1.610198
# Raining with high winds               1.174488
# Fine with high winds                  1.160679
# Other                                 0.653504
# Snowing without high winds            0.623437
# Fog or mist                           0.319803
# Snowing with high winds               0.154950
# Darkness: street lighting unknown     0.078958
# dtype: float64

# %%
mean_values.iloc[2:].plot(kind='barh',
                        title ="2009 to 2018 Mean percentage (%)",
                        figsize = (10,8),
                        grid=True
                        );

# %% [markdown]
# - Most of the accidents occur during fine weather conditions (86.2%) without high winds.
# - Next contributing weather condition for accidents is Rain (9.68%) combining with and without high winds.
# - Fog, mist and snow comditions sums upto less than 2% of the overall accidents over the years.
# - Noticeably, high wind has less effect on accidnets as the data was recorded in urban and suburban zones mostly.

# %% [markdown]
# #### Number of accident per year by Road Surface

# %%
road_surface_percent=(data.resample('Y')["road_surface"].value_counts(normalize=True)*100).sort_values(ascending=True).unstack()
road_surface_percent.mean()
# Out:
# road_surface
# Dry          74.377697
# Flood         0.149664
# Frost/Ice     1.235073
# Snow          0.712036
# Wet/Damp     23.585394
# dtype: float64

# %%
road_surface_percent.plot(sharex=True,
                          subplots=True,
                          marker='o',
                          title ="road surface causing accidents",
                          xlabel="year",
                          figsize = (10,8),
                          grid=True
                        );
plt.subplots_adjust(hspace=0.1) 
axes[0].set_ylabel('Dry (%)');
axes[1].set_ylabel('Flood (%)');
axes[2].set_ylabel('Slight (%)');

# %% [markdown]
# - Highest number of accidents happend when the road surface is dry.
#
# - Least  number of accidents happend when there is flooding

# %% [markdown]
# #### Highest Number of accident  by month

# %%
# Number of accident per month
accidents_month=data.groupby([data.index.month]).count()
accidents_month
# Replace the month integers by month names.
accidents_month.index=[calendar.month_name[x] for x in range(1,13)]
accidents_month


# plot accidents per month
accidents_month.plot(kind='bar',figsize=(12,7), color='blue', alpha=0.5,legend=False)

# title and x,y labels
plt.title('Accidents in Uk from year 2009to2018', fontsize=20)
plt.xlabel('Month',fontsize=16)
plt.ylabel('Accidents',fontsize=16);

# %% [markdown]
# - From the above analysis maxiumn number of accidents are happend in the month of october followed by November.

# %% [markdown]
# #### Coverting Easting and Northing to Latitude and Longitude

# %%
#By using covert_lonlat method from convertbng.util library converting to logitude and latitude
list_lon_lat = convert_lonlat(data.easting, data.northing)
data['longitude'] = list_lon_lat[0]
data['latitude'] = list_lon_lat[1]

# %%
locations = data[['latitude', 'longitude']]
locationlist = locations.values.tolist()
len(locationlist)
#print(locationlist)
locationlist[0]
# Out:
# [53.82180298, -1.55955206]

# %% [markdown]
# ##### All type of vehicle locations Random sample 100

# %%
from random import sample
sample_location_100 = sample(locationlist,100)

# %%
map = folium.Map(location=[53.82180298, -1.55955206], zoom_start=12)
for point in range(0, len(sample_location_100)):
    folium.Marker(sample_location_100[point], tooltip=data['type_of_vehicle'][point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4152d39c47c04a87a2758b40a3f4eab7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4152d39c47c04a87a2758b40a3f4eab7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4152d39c47c04a87a2758b40a3f4eab7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4152d39c47c04a87a2758b40a3f4eab7%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B53.82180298%2C%20-1.55955206%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ##### Car Accident locations Random Sample 100

# %%
locations_car = data[data.type_of_vehicle == 'Car'][['latitude', 'longitude']]
locationlist_car = (locations_car[['latitude', 'longitude']]).values.tolist()
len(locationlist_car)
locationlist_car[0]
# Out:
# [53.82180298, -1.55955206]

# %%
sample_location_car_100 = sample(locationlist_car,100)

map = folium.Map(location=[53.82180298, -1.55955206], zoom_start=12)
for point in range(0, len(sample_location_car_100)):
    folium.Marker(sample_location_car_100[point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ebffe42a55994b7db9e201c0e626ece9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ebffe42a55994b7db9e201c0e626ece9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ebffe42a55994b7db9e201c0e626ece9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ebffe42a55994b7db9e201c0e626ece9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B53.82180298%2C%20-1.55955206%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ##### Pedal cycle Accident locations Random Sample 100

# %%
#locations_pcycle = data[data.type_of_vehicle == 'Pedal cycle'][['latitude', 'longitude']]
locations_pcycle = data[data.type_of_vehicle.eq("Pedal cycle")][['latitude', 'longitude']]
locationlist_pcycle = (locations_pcycle[['latitude', 'longitude']]).values.tolist()
len(locationlist_pcycle)
locationlist_pcycle[0]
# Out:
# [53.82310283, -1.61337338]

# %%
sample_location_pcycle_100 = sample(locationlist_pcycle,100)

map = folium.Map(location=[53.82310283, -1.61337338], zoom_start=12)
for point in range(0, len(sample_location_pcycle_100)):
    folium.Marker(sample_location_pcycle_100[point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5a3cde53611a4622af4429207b8ba688%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5a3cde53611a4622af4429207b8ba688%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_5a3cde53611a4622af4429207b8ba688%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_5a3cde53611a4622af4429207b8ba688%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B53.82310283%2C%20-1.61337338%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ##### Motorcycle cycle Accident locations Random Sample 100

# %%
locations_mcycle = data[data.type_of_vehicle == 'Motorcycle'][['latitude', 'longitude']]
locationlist_mcycle = (locations_mcycle[['latitude', 'longitude']]).values.tolist()
len(locationlist_mcycle)
locationlist_mcycle[0]
# Out:
# [53.83762698, -1.64241767]

# %%
sample_location_mcycle_100 = sample(locationlist_mcycle,100)

map = folium.Map(location=[53.82310283, -1.61337338], zoom_start=12)
for point in range(0, len(sample_location_mcycle_100)):
    folium.Marker(sample_location_mcycle_100[point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_bca3c3eb843b42ac97f956c901881d56%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_bca3c3eb843b42ac97f956c901881d56%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_bca3c3eb843b42ac97f956c901881d56%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_bca3c3eb843b42ac97f956c901881d56%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B53.82310283%2C%20-1.61337338%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ##### By using pandas_profiling we can read Profile Report

# %%
#profileReport(data)

# %% [markdown]
# ##### Analysis and visualizaion by Class, Severity and Sex of Casualty

# %%
data.columns
# Out:
# Index(['reference_number', 'easting', 'northing', 'number_of_vehicles',
#        '1st_road_class', 'road_surface', 'lighting_conditions',
#        'weather_conditions', 'casualty_class', 'casualty_severity',
#        'sex_of_casualty', 'age_of_casualty', 'type_of_vehicle',
#        'casualty_class.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
(data['sex_of_casualty'].value_counts(normalize=True)*100)
# Out:
# Male      58.748488
# Female    41.251512
# Name: sex_of_casualty, dtype: float64

# %% [markdown]
# - Male percentage is involved higher in accidents

# %%
df_sex_cas_cls =(data.groupby('sex_of_casualty')['casualty_severity'].value_counts(normalize=True)*100).unstack()
df_sex_cas_cls.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_c24e3_row0_col0, #T_c24e3_row0_col1, #T_c24e3_row1_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c24e3_row0_col2, #T_c24e3_row1_col0, #T_c24e3_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c24e3_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >casualty_severity</th>
#       <th class="col_heading level0 col0" >Fatal</th>
#       <th class="col_heading level0 col1" >Serious</th>
#       <th class="col_heading level0 col2" >Slight</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sex_of_casualty</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c24e3_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_c24e3_row0_col0" class="data row0 col0" >0.482315</td>
#       <td id="T_c24e3_row0_col1" class="data row0 col1" >8.511443</td>
#       <td id="T_c24e3_row0_col2" class="data row0 col2" >91.006242</td>
#     </tr>
#     <tr>
#       <th id="T_c24e3_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_c24e3_row1_col0" class="data row1 col0" >0.896474</td>
#       <td id="T_c24e3_row1_col1" class="data row1 col1" >13.938509</td>
#       <td id="T_c24e3_row1_col2" class="data row1 col2" >85.165018</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# df_sex_cas_cls =(data.groupby('sex_of_casualty')['casualty_severity']["type_of_vechicle].value_counts(normalize=True)*100).unstack()
# df_sex_cas_cls.style.background_gradient(cmap='Blues')

# %% [markdown]
# - Male serious and Fatal accident casualty percentage is comparetively higher than the Female.
# - A large percentage of accidents casualty involving female is slight and least is Fatal.

# %%
df_sex_cas_cls =(data.groupby('sex_of_casualty')['casualty_class'].value_counts(normalize=True)*100).unstack()
df_sex_cas_cls.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_c3861_row0_col0, #T_c3861_row1_col1, #T_c3861_row1_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c3861_row0_col1, #T_c3861_row0_col2, #T_c3861_row1_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c3861_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >casualty_class</th>
#       <th class="col_heading level0 col0" >Driver/Rider</th>
#       <th class="col_heading level0 col1" >Passenger</th>
#       <th class="col_heading level0 col2" >Pedestrian</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sex_of_casualty</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3861_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_c3861_row0_col0" class="data row0 col0" >45.432192</td>
#       <td id="T_c3861_row0_col1" class="data row0 col1" >39.332325</td>
#       <td id="T_c3861_row0_col2" class="data row0 col2" >15.235483</td>
#     </tr>
#     <tr>
#       <th id="T_c3861_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_c3861_row1_col0" class="data row1 col0" >67.521084</td>
#       <td id="T_c3861_row1_col1" class="data row1 col1" >18.693140</td>
#       <td id="T_c3861_row1_col2" class="data row1 col2" >13.785776</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Male drivers are significantly more involved in accidents.
# - A large portion of casulaty class for Female consists of Passenger class

# %% [markdown]
# ###### Gender analysis by type of vehicles
# - Overall type of vehicle percentage for each Gender.

# %%
df_sex_cas_cls =(data.groupby('sex_of_casualty')['type_of_vehicle'].value_counts(normalize=True)*100).unstack().T
df_sex_cas_cls.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_c850e_row0_col0, #T_c850e_row0_col1, #T_c850e_row4_col0, #T_c850e_row5_col0, #T_c850e_row5_col1, #T_c850e_row7_col0, #T_c850e_row9_col0, #T_c850e_row9_col1, #T_c850e_row11_col0, #T_c850e_row11_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c850e_row1_col0 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_c850e_row1_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_c850e_row2_col0, #T_c850e_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c850e_row3_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_c850e_row3_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_c850e_row4_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_c850e_row6_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_c850e_row6_col1 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_c850e_row7_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_c850e_row8_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_c850e_row8_col1 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_c850e_row10_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_c850e_row10_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# </style>
# <table id="T_c850e_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >sex_of_casualty</th>
#       <th class="col_heading level0 col0" >Female</th>
#       <th class="col_heading level0 col1" >Male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >type_of_vehicle</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c850e_level0_row0" class="row_heading level0 row0" >Agricultural vehicle (includes diggers etc.)</th>
#       <td id="T_c850e_row0_col0" class="data row0 col0" >0.009458</td>
#       <td id="T_c850e_row0_col1" class="data row0 col1" >0.053124</td>
#     </tr>
#     <tr>
#       <th id="T_c850e_level0_row1" class="row_heading level0 row1" >Bus</th>
#       <td id="T_c850e_row1_col0" class="data row1 col0" >8.909486</td>
#       <td id="T_c850e_row1_col1" class="data row1 col1" >3.599177</td>
#     </tr>
#     <tr>
#       <th id="T_c850e_level0_row2" class="row_heading level0 row2" >Car</th>
#       <td id="T_c850e_row2_col0" class="data row2 col0" >78.057316</td>
#       <td id="T_c850e_row2_col1" class="data row2 col1" >59.021183</td>
#     </tr>
#     <tr>
#       <th id="T_c850e_level0_row3" class="row_heading level0 row3" >Goods Vehicle</th>
#       <td id="T_c850e_row3_col0" class="data row3 col0" >1.295753</td>
#       <td id="T_c850e_row3_col1" class="data row3 col1" >4.296434</td>
#     </tr>
#     <tr>
#       <th id="T_c850e_level0_row4" class="row_heading level0 row4" >Minibus</th>
#       <td id="T_c850e_row4_col0" class="data row4 col0" >0.293200</td>
#       <td id="T_c850e_row4_col1" class="data row4 col1" >0.431636</td>
#     </tr>
#     <tr>
#       <th id="T_c850e_level0_row5" class="row_heading level0 row5" >Mobility Scooter</th>
#       <td id="T_c850e_row5_col0" class="data row5 col0" >0.094581</td>
#       <td id="T_c850e_row5_col1" class="data row5 col1" >0.059765</td>
#     </tr>
#     <tr>
#       <th id="T_c850e_level0_row6" class="row_heading level0 row6" >Motorcycle</th>
#       <td id="T_c850e_row6_col0" class="data row6 col0" >2.118604</td>
#       <td id="T_c850e_row6_col1" class="data row6 col1" >11.023308</td>
#     </tr>
#     <tr>
#       <th id="T_c850e_level0_row7" class="row_heading level0 row7" >Other Vehicle </th>
#       <td id="T_c850e_row7_col0" class="data row7 col0" >0.283742</td>
#       <td id="T_c850e_row7_col1" class="data row7 col1" >0.604290</td>
#     </tr>
#     <tr>
#       <th id="T_c850e_level0_row8" class="row_heading level0 row8" >Pedal cycle</th>
#       <td id="T_c850e_row8_col0" class="data row8 col0" >5.315426</td>
#       <td id="T_c850e_row8_col1" class="data row8 col1" >16.986520</td>
#     </tr>
#     <tr>
#       <th id="T_c850e_level0_row9" class="row_heading level0 row9" >Ridden horse</th>
#       <td id="T_c850e_row9_col0" class="data row9 col0" >0.047290</td>
#       <td id="T_c850e_row9_col1" class="data row9 col1" >0.013281</td>
#     </tr>
#     <tr>
#       <th id="T_c850e_level0_row10" class="row_heading level0 row10" >Taxi/Hire</th>
#       <td id="T_c850e_row10_col0" class="data row10 col0" >3.556228</td>
#       <td id="T_c850e_row10_col1" class="data row10 col1" >3.904642</td>
#     </tr>
#     <tr>
#       <th id="T_c850e_level0_row11" class="row_heading level0 row11" >Tram / Light rail</th>
#       <td id="T_c850e_row11_col0" class="data row11 col0" >0.018916</td>
#       <td id="T_c850e_row11_col1" class="data row11 col1" >0.006641</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Car accident percentage is the highest for both male and female
# - Male involvment in Pedal cycle and Motorcycle is significantly higher.

# %% [markdown]
# ###### Type of vehicle analysis by Gender
# - For each type of vehicle the Male and Female percentage

# %%
df_sex_cas_cls =(data.groupby('type_of_vehicle')['sex_of_casualty'].value_counts(normalize=True)*100).unstack()
df_sex_cas_cls.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_192e4_row0_col0, #T_192e4_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_192e4_row0_col1, #T_192e4_row9_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_192e4_row1_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_192e4_row1_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_192e4_row2_col0 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_192e4_row2_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_192e4_row3_col0 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_192e4_row3_col1 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_192e4_row4_col0 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_192e4_row4_col1 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_192e4_row5_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_192e4_row5_col1 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_192e4_row6_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_192e4_row6_col1 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_192e4_row7_col0 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_192e4_row7_col1 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_192e4_row8_col0 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_192e4_row8_col1 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_192e4_row10_col0 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_192e4_row10_col1 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_192e4_row11_col0 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_192e4_row11_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# </style>
# <table id="T_192e4_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >sex_of_casualty</th>
#       <th class="col_heading level0 col0" >Female</th>
#       <th class="col_heading level0 col1" >Male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >type_of_vehicle</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_192e4_level0_row0" class="row_heading level0 row0" >Agricultural vehicle (includes diggers etc.)</th>
#       <td id="T_192e4_row0_col0" class="data row0 col0" >11.111111</td>
#       <td id="T_192e4_row0_col1" class="data row0 col1" >88.888889</td>
#     </tr>
#     <tr>
#       <th id="T_192e4_level0_row1" class="row_heading level0 row1" >Bus</th>
#       <td id="T_192e4_row1_col0" class="data row1 col0" >63.477089</td>
#       <td id="T_192e4_row1_col1" class="data row1 col1" >36.522911</td>
#     </tr>
#     <tr>
#       <th id="T_192e4_level0_row2" class="row_heading level0 row2" >Car</th>
#       <td id="T_192e4_row2_col0" class="data row2 col0" >48.147716</td>
#       <td id="T_192e4_row2_col1" class="data row2 col1" >51.852284</td>
#     </tr>
#     <tr>
#       <th id="T_192e4_level0_row3" class="row_heading level0 row3" >Goods Vehicle</th>
#       <td id="T_192e4_row3_col0" class="data row3 col0" >17.474490</td>
#       <td id="T_192e4_row3_col1" class="data row3 col1" >82.525510</td>
#     </tr>
#     <tr>
#       <th id="T_192e4_level0_row4" class="row_heading level0 row4" >Minibus</th>
#       <td id="T_192e4_row4_col0" class="data row4 col0" >32.291667</td>
#       <td id="T_192e4_row4_col1" class="data row4 col1" >67.708333</td>
#     </tr>
#     <tr>
#       <th id="T_192e4_level0_row5" class="row_heading level0 row5" >Mobility Scooter</th>
#       <td id="T_192e4_row5_col0" class="data row5 col0" >52.631579</td>
#       <td id="T_192e4_row5_col1" class="data row5 col1" >47.368421</td>
#     </tr>
#     <tr>
#       <th id="T_192e4_level0_row6" class="row_heading level0 row6" >Motorcycle</th>
#       <td id="T_192e4_row6_col0" class="data row6 col0" >11.889597</td>
#       <td id="T_192e4_row6_col1" class="data row6 col1" >88.110403</td>
#     </tr>
#     <tr>
#       <th id="T_192e4_level0_row7" class="row_heading level0 row7" >Other Vehicle </th>
#       <td id="T_192e4_row7_col0" class="data row7 col0" >24.793388</td>
#       <td id="T_192e4_row7_col1" class="data row7 col1" >75.206612</td>
#     </tr>
#     <tr>
#       <th id="T_192e4_level0_row8" class="row_heading level0 row8" >Pedal cycle</th>
#       <td id="T_192e4_row8_col0" class="data row8 col0" >18.012821</td>
#       <td id="T_192e4_row8_col1" class="data row8 col1" >81.987179</td>
#     </tr>
#     <tr>
#       <th id="T_192e4_level0_row9" class="row_heading level0 row9" >Ridden horse</th>
#       <td id="T_192e4_row9_col0" class="data row9 col0" >71.428571</td>
#       <td id="T_192e4_row9_col1" class="data row9 col1" >28.571429</td>
#     </tr>
#     <tr>
#       <th id="T_192e4_level0_row10" class="row_heading level0 row10" >Taxi/Hire</th>
#       <td id="T_192e4_row10_col0" class="data row10 col0" >39.004149</td>
#       <td id="T_192e4_row10_col1" class="data row10 col1" >60.995851</td>
#     </tr>
#     <tr>
#       <th id="T_192e4_level0_row11" class="row_heading level0 row11" >Tram / Light rail</th>
#       <td id="T_192e4_row11_col0" class="data row11 col0" >66.666667</td>
#       <td id="T_192e4_row11_col1" class="data row11 col1" >33.333333</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Male involvment in car accident is slightly higher than Female.
# - Male involvment in Pedal cycle and Motorcycle is significantly higher than Female.

# %%
data[data.number_of_vehicles>2]['type_of_vehicle'].value_counts(normalize=True)*100
# Out:
# Car                  83.539343
# Goods Vehicle         5.004522
# Pedal cycle           3.527284
# Motorcycle            3.255954
# Taxi/Hire             2.110341
# Bus                   1.507386
# Other Vehicle         0.482364
# Minibus               0.452216
# Tram / Light rail     0.090443
# Ridden horse          0.030148
# Name: type_of_vehicle, dtype: float64

# %% [markdown]
# - In multiple vehicle crash Car is the most common vehicle as expected.
# - Goods vehicle, Pedal cycle and Motorcycle come next in consecutive orders.
# - Among the large vehicles Goods vehicles are more involved in multiple vehicle crash, whereas, Bus, Minibus or Tram are very less involved.

# %% [markdown]
# ###### Stats for Casualty Severity 1
# - Below chart shows the percentage of vehicles involved in each class of severity.
# - Car has the higest percentage of share for each class of severity.
# - Motorcycle and Pedal cycle also has significant share in all the casualty class.
# - Goods vehicle stands in between Motorcycle and Pedal cycle regarding Fatal accidents.

# %%
df_cas_sev_type_veh=(data.groupby('casualty_severity')['type_of_vehicle'].value_counts(ascending=True,normalize=True)*100).unstack().T
df_cas_sev_type_veh=df_cas_sev_type_veh.fillna(0)
df_cas_sev_type_veh.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_830d0_row0_col0, #T_830d0_row0_col1, #T_830d0_row0_col2, #T_830d0_row4_col0, #T_830d0_row5_col0, #T_830d0_row5_col1, #T_830d0_row5_col2, #T_830d0_row9_col0, #T_830d0_row9_col1, #T_830d0_row9_col2, #T_830d0_row11_col0, #T_830d0_row11_col1, #T_830d0_row11_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_830d0_row1_col0 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_830d0_row1_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_830d0_row1_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_830d0_row2_col0, #T_830d0_row2_col1, #T_830d0_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_830d0_row3_col0 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_830d0_row3_col1, #T_830d0_row10_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_830d0_row3_col2, #T_830d0_row10_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_830d0_row4_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_830d0_row4_col2, #T_830d0_row7_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_830d0_row6_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_830d0_row6_col1 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_830d0_row6_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_830d0_row7_col0, #T_830d0_row10_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_830d0_row7_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_830d0_row8_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_830d0_row8_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_830d0_row8_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# </style>
# <table id="T_830d0_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >casualty_severity</th>
#       <th class="col_heading level0 col0" >Fatal</th>
#       <th class="col_heading level0 col1" >Serious</th>
#       <th class="col_heading level0 col2" >Slight</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >type_of_vehicle</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_830d0_level0_row0" class="row_heading level0 row0" >Agricultural vehicle (includes diggers etc.)</th>
#       <td id="T_830d0_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_830d0_row0_col1" class="data row0 col1" >0.033344</td>
#       <td id="T_830d0_row0_col2" class="data row0 col2" >0.035640</td>
#     </tr>
#     <tr>
#       <th id="T_830d0_level0_row1" class="row_heading level0 row1" >Bus</th>
#       <td id="T_830d0_row1_col0" class="data row1 col0" >3.225806</td>
#       <td id="T_830d0_row1_col1" class="data row1 col1" >3.501167</td>
#       <td id="T_830d0_row1_col2" class="data row1 col2" >6.116630</td>
#     </tr>
#     <tr>
#       <th id="T_830d0_level0_row2" class="row_heading level0 row2" >Car</th>
#       <td id="T_830d0_row2_col0" class="data row2 col0" >60.752688</td>
#       <td id="T_830d0_row2_col1" class="data row2 col1" >50.883628</td>
#       <td id="T_830d0_row2_col2" class="data row2 col2" >69.060454</td>
#     </tr>
#     <tr>
#       <th id="T_830d0_level0_row3" class="row_heading level0 row3" >Goods Vehicle</th>
#       <td id="T_830d0_row3_col0" class="data row3 col0" >11.290323</td>
#       <td id="T_830d0_row3_col1" class="data row3 col1" >2.900967</td>
#       <td id="T_830d0_row3_col2" class="data row3 col2" >3.011538</td>
#     </tr>
#     <tr>
#       <th id="T_830d0_level0_row4" class="row_heading level0 row4" >Minibus</th>
#       <td id="T_830d0_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_830d0_row4_col1" class="data row4 col1" >0.400133</td>
#       <td id="T_830d0_row4_col2" class="data row4 col2" >0.374215</td>
#     </tr>
#     <tr>
#       <th id="T_830d0_level0_row5" class="row_heading level0 row5" >Mobility Scooter</th>
#       <td id="T_830d0_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_830d0_row5_col1" class="data row5 col1" >0.166722</td>
#       <td id="T_830d0_row5_col2" class="data row5 col2" >0.062369</td>
#     </tr>
#     <tr>
#       <th id="T_830d0_level0_row6" class="row_heading level0 row6" >Motorcycle</th>
#       <td id="T_830d0_row6_col0" class="data row6 col0" >16.666667</td>
#       <td id="T_830d0_row6_col1" class="data row6 col1" >21.407136</td>
#       <td id="T_830d0_row6_col2" class="data row6 col2" >5.394930</td>
#     </tr>
#     <tr>
#       <th id="T_830d0_level0_row7" class="row_heading level0 row7" >Other Vehicle </th>
#       <td id="T_830d0_row7_col0" class="data row7 col0" >1.612903</td>
#       <td id="T_830d0_row7_col1" class="data row7 col1" >0.833611</td>
#       <td id="T_830d0_row7_col2" class="data row7 col2" >0.414309</td>
#     </tr>
#     <tr>
#       <th id="T_830d0_level0_row8" class="row_heading level0 row8" >Pedal cycle</th>
#       <td id="T_830d0_row8_col0" class="data row8 col0" >4.838710</td>
#       <td id="T_830d0_row8_col1" class="data row8 col1" >17.305769</td>
#       <td id="T_830d0_row8_col2" class="data row8 col2" >11.547200</td>
#     </tr>
#     <tr>
#       <th id="T_830d0_level0_row9" class="row_heading level0 row9" >Ridden horse</th>
#       <td id="T_830d0_row9_col0" class="data row9 col0" >0.000000</td>
#       <td id="T_830d0_row9_col1" class="data row9 col1" >0.033344</td>
#       <td id="T_830d0_row9_col2" class="data row9 col2" >0.026730</td>
#     </tr>
#     <tr>
#       <th id="T_830d0_level0_row10" class="row_heading level0 row10" >Taxi/Hire</th>
#       <td id="T_830d0_row10_col0" class="data row10 col0" >1.612903</td>
#       <td id="T_830d0_row10_col1" class="data row10 col1" >2.534178</td>
#       <td id="T_830d0_row10_col2" class="data row10 col2" >3.942620</td>
#     </tr>
#     <tr>
#       <th id="T_830d0_level0_row11" class="row_heading level0 row11" >Tram / Light rail</th>
#       <td id="T_830d0_row11_col0" class="data row11 col0" >0.000000</td>
#       <td id="T_830d0_row11_col1" class="data row11 col1" >0.000000</td>
#       <td id="T_830d0_row11_col2" class="data row11 col2" >0.013365</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ###### Stats for Casualty Severity 2
# - Below chart shows the percentage of class of severity for each vehicle types.
# - Most of the accidents for Car are slight in severity.
# - For Motorcycle accidents Serious severity is signficanlty higher.
# - Goods vehicle accidents are significantly fatal.

# %%
df_type_veh_cas_sev=(data.groupby('type_of_vehicle')['casualty_severity'].value_counts(ascending=True,normalize=True)*100).unstack()
df_type_veh_cas_sev=df_type_veh_cas_sev.fillna(0)
df_type_veh_cas_sev.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_be0a4_row0_col0, #T_be0a4_row4_col0, #T_be0a4_row5_col0, #T_be0a4_row6_col2, #T_be0a4_row9_col0, #T_be0a4_row11_col0, #T_be0a4_row11_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_be0a4_row0_col1, #T_be0a4_row3_col1 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_be0a4_row0_col2 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_be0a4_row1_col0 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_be0a4_row1_col1 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_be0a4_row1_col2 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_be0a4_row2_col0 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_be0a4_row2_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_be0a4_row2_col2 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_be0a4_row3_col0, #T_be0a4_row6_col1, #T_be0a4_row11_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_be0a4_row3_col2, #T_be0a4_row6_col0 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_be0a4_row4_col1 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_be0a4_row4_col2 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_be0a4_row5_col1, #T_be0a4_row10_col2 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_be0a4_row5_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_be0a4_row7_col0 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_be0a4_row7_col1 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_be0a4_row7_col2 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_be0a4_row8_col0 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_be0a4_row8_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_be0a4_row8_col2 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_be0a4_row9_col1 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_be0a4_row9_col2 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_be0a4_row10_col0 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_be0a4_row10_col1 {
#   background-color: #caddf0;
#   color: #000000;
# }
# </style>
# <table id="T_be0a4_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >casualty_severity</th>
#       <th class="col_heading level0 col0" >Fatal</th>
#       <th class="col_heading level0 col1" >Serious</th>
#       <th class="col_heading level0 col2" >Slight</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >type_of_vehicle</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be0a4_level0_row0" class="row_heading level0 row0" >Agricultural vehicle (includes diggers etc.)</th>
#       <td id="T_be0a4_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_be0a4_row0_col1" class="data row0 col1" >11.111111</td>
#       <td id="T_be0a4_row0_col2" class="data row0 col2" >88.888889</td>
#     </tr>
#     <tr>
#       <th id="T_be0a4_level0_row1" class="row_heading level0 row1" >Bus</th>
#       <td id="T_be0a4_row1_col0" class="data row1 col0" >0.404313</td>
#       <td id="T_be0a4_row1_col1" class="data row1 col1" >7.075472</td>
#       <td id="T_be0a4_row1_col2" class="data row1 col2" >92.520216</td>
#     </tr>
#     <tr>
#       <th id="T_be0a4_level0_row2" class="row_heading level0 row2" >Car</th>
#       <td id="T_be0a4_row2_col0" class="data row2 col0" >0.659238</td>
#       <td id="T_be0a4_row2_col1" class="data row2 col1" >8.902631</td>
#       <td id="T_be0a4_row2_col2" class="data row2 col2" >90.438131</td>
#     </tr>
#     <tr>
#       <th id="T_be0a4_level0_row3" class="row_heading level0 row3" >Goods Vehicle</th>
#       <td id="T_be0a4_row3_col0" class="data row3 col0" >2.678571</td>
#       <td id="T_be0a4_row3_col1" class="data row3 col1" >11.096939</td>
#       <td id="T_be0a4_row3_col2" class="data row3 col2" >86.224490</td>
#     </tr>
#     <tr>
#       <th id="T_be0a4_level0_row4" class="row_heading level0 row4" >Minibus</th>
#       <td id="T_be0a4_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_be0a4_row4_col1" class="data row4 col1" >12.500000</td>
#       <td id="T_be0a4_row4_col2" class="data row4 col2" >87.500000</td>
#     </tr>
#     <tr>
#       <th id="T_be0a4_level0_row5" class="row_heading level0 row5" >Mobility Scooter</th>
#       <td id="T_be0a4_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_be0a4_row5_col1" class="data row5 col1" >26.315789</td>
#       <td id="T_be0a4_row5_col2" class="data row5 col2" >73.684211</td>
#     </tr>
#     <tr>
#       <th id="T_be0a4_level0_row6" class="row_heading level0 row6" >Motorcycle</th>
#       <td id="T_be0a4_row6_col0" class="data row6 col0" >1.645435</td>
#       <td id="T_be0a4_row6_col1" class="data row6 col1" >34.076433</td>
#       <td id="T_be0a4_row6_col2" class="data row6 col2" >64.278132</td>
#     </tr>
#     <tr>
#       <th id="T_be0a4_level0_row7" class="row_heading level0 row7" >Other Vehicle </th>
#       <td id="T_be0a4_row7_col0" class="data row7 col0" >2.479339</td>
#       <td id="T_be0a4_row7_col1" class="data row7 col1" >20.661157</td>
#       <td id="T_be0a4_row7_col2" class="data row7 col2" >76.859504</td>
#     </tr>
#     <tr>
#       <th id="T_be0a4_level0_row8" class="row_heading level0 row8" >Pedal cycle</th>
#       <td id="T_be0a4_row8_col0" class="data row8 col0" >0.288462</td>
#       <td id="T_be0a4_row8_col1" class="data row8 col1" >16.634615</td>
#       <td id="T_be0a4_row8_col2" class="data row8 col2" >83.076923</td>
#     </tr>
#     <tr>
#       <th id="T_be0a4_level0_row9" class="row_heading level0 row9" >Ridden horse</th>
#       <td id="T_be0a4_row9_col0" class="data row9 col0" >0.000000</td>
#       <td id="T_be0a4_row9_col1" class="data row9 col1" >14.285714</td>
#       <td id="T_be0a4_row9_col2" class="data row9 col2" >85.714286</td>
#     </tr>
#     <tr>
#       <th id="T_be0a4_level0_row10" class="row_heading level0 row10" >Taxi/Hire</th>
#       <td id="T_be0a4_row10_col0" class="data row10 col0" >0.311203</td>
#       <td id="T_be0a4_row10_col1" class="data row10 col1" >7.883817</td>
#       <td id="T_be0a4_row10_col2" class="data row10 col2" >91.804979</td>
#     </tr>
#     <tr>
#       <th id="T_be0a4_level0_row11" class="row_heading level0 row11" >Tram / Light rail</th>
#       <td id="T_be0a4_row11_col0" class="data row11 col0" >0.000000</td>
#       <td id="T_be0a4_row11_col1" class="data row11 col1" >0.000000</td>
#       <td id="T_be0a4_row11_col2" class="data row11 col2" >100.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Car is the most involved vehicle in all class of accidents.
# - Motorcycle and Goods vehicle comes next

# %% [markdown]
# ##### Location Analysis

# %%
data.columns
# Out:
# Index(['reference_number', 'easting', 'northing', 'number_of_vehicles',
#        '1st_road_class', 'road_surface', 'lighting_conditions',
#        'weather_conditions', 'casualty_class', 'casualty_severity',
#        'sex_of_casualty', 'age_of_casualty', 'type_of_vehicle',
#        'casualty_class.1', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# Fatal Accidents Locations

# %%
df_fatal_loc=data[data.casualty_severity=='Fatal'][['latitude','longitude']].drop_duplicates()
locations_fatal = df_fatal_loc[['latitude', 'longitude']]
locationlist_fatal = (locations_fatal[['latitude', 'longitude']]).values.tolist()
len(locationlist_fatal)
locationlist_fatal[0]
# Out:
# [53.76988352, -1.57834607]

# %%
map = folium.Map(location=[53.76988352, -1.57834607], zoom_start=12)
for point in range(0, len(locationlist_fatal)):
    folium.Marker(locationlist_fatal[point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_dcfe98e0572f41168155b4234f4cb1f5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_dcfe98e0572f41168155b4234f4cb1f5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_dcfe98e0572f41168155b4234f4cb1f5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_dcfe98e0572f41168155b4234f4cb1f5%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B53.76988352%2C%20-1.57834607%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
df_cas_cls_road_type=(data.groupby('casualty_severity')['1st_road_class'].value_counts(normalize=True)*100).unstack().T
df_cas_cls_road_type=df_cas_cls_road_type.fillna(0)
df_cas_cls_road_type.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_fb955_row0_col0, #T_fb955_row4_col1, #T_fb955_row4_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fb955_row0_col1 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_fb955_row0_col2 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_fb955_row1_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_fb955_row1_col1 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_fb955_row1_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_fb955_row2_col0, #T_fb955_row2_col1, #T_fb955_row2_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fb955_row3_col0, #T_fb955_row3_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_fb955_row3_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_fb955_row4_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fb955_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >casualty_severity</th>
#       <th class="col_heading level0 col0" >Fatal</th>
#       <th class="col_heading level0 col1" >Serious</th>
#       <th class="col_heading level0 col2" >Slight</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >1st_road_class</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb955_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_fb955_row0_col0" class="data row0 col0" >51.612903</td>
#       <td id="T_fb955_row0_col1" class="data row0 col1" >35.811937</td>
#       <td id="T_fb955_row0_col2" class="data row0 col2" >38.542409</td>
#     </tr>
#     <tr>
#       <th id="T_fb955_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_fb955_row1_col0" class="data row1 col0" >6.989247</td>
#       <td id="T_fb955_row1_col1" class="data row1 col1" >5.968656</td>
#       <td id="T_fb955_row1_col2" class="data row1 col2" >5.287776</td>
#     </tr>
#     <tr>
#       <th id="T_fb955_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_fb955_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_fb955_row2_col1" class="data row2 col1" >0.233411</td>
#       <td id="T_fb955_row2_col2" class="data row2 col2" >0.120278</td>
#     </tr>
#     <tr>
#       <th id="T_fb955_level0_row3" class="row_heading level0 row3" >Motorway</th>
#       <td id="T_fb955_row3_col0" class="data row3 col0" >4.301075</td>
#       <td id="T_fb955_row3_col1" class="data row3 col1" >4.668223</td>
#       <td id="T_fb955_row3_col2" class="data row3 col2" >6.833571</td>
#     </tr>
#     <tr>
#       <th id="T_fb955_level0_row4" class="row_heading level0 row4" >Unclassified</th>
#       <td id="T_fb955_row4_col0" class="data row4 col0" >37.096774</td>
#       <td id="T_fb955_row4_col1" class="data row4 col1" >53.317773</td>
#       <td id="T_fb955_row4_col2" class="data row4 col2" >49.215966</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Most of the Fatal accidents occured on class-A roads.

# %% [markdown]
# ### Conclusion
# #### Observation summary:
# - Most dangerous conditions to drive in uk is dry road surface,daylight: street lights present,fine weather conditions without high winds.
# - Car is one met maxium number of accidents.
# - prime working age people and male are most affected.
# - The most dangerous month is october to drive.
# -
# Road Accident has always been a devastating factor of human lives. With the ever increasing number of vehicles it is really important to account for this devasting aspect of human lives. There is further analysis scope with this data if the reason of the accidents are included as well.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=de8a8f15-3c85-4deb-b956-051fdca6483d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
